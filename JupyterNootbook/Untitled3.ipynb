# %%
import numpy as np

# %%
from sklearn.svm import SVR
import matplotlib.pyplot as plt

# %%
X  = np.sort(5 * np.random.rand(40,1), axis=0)
y = np.sin(X).ravel()

# %%
y[::5] += 3*(0.5-np.random.rand(8))

# %%
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)

# %%
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()

# %%
y[::5]
# Out:
# array([ 0.74144127,  0.38865245,  0.74796484,  1.13768339,  0.13331302,
#        -0.03361183,  0.52189843, -0.89428622])

# %%
y[:5]
# Out:
# array([0.74144127, 0.40314817, 0.43504778, 0.44002087, 0.75108583])

# %%
y.shape
# Out:
# (40,)

# %%
y
# Out:
# array([ 0.74144127,  0.40314817,  0.43504778,  0.44002087,  0.75108583,
#         0.38865245,  0.88389819,  0.94957242,  0.95306371,  0.97493179,
#         0.74796484,  0.99956614,  0.97786731,  0.9447794 ,  0.86485544,
#         1.13768339,  0.79507497,  0.7247976 ,  0.69746391,  0.67765191,
#         0.13331302,  0.59129348,  0.37801678,  0.36056   ,  0.34278039,
#        -0.03361183,  0.11709035, -0.2446683 , -0.40932271, -0.46187226,
#         0.52189843, -0.63525181, -0.70741906, -0.76222939, -0.92787957,
#        -0.89428622, -0.98433802, -0.99923595, -0.99977103, -0.9933389 ])
